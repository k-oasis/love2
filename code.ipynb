# %%
import warnings
import logging

root_logger = logging.getLogger()
root_logger.setLevel(logging.ERROR)
warnings.filterwarnings('ignore')

# %%
from metagpt.tools.libs.terminal import Terminal

terminal = Terminal()

commands = [
    'echo "# love" >> README.md',
    'git init',
    'git add README.md',
    'git commit -m "first commit"',
    'git branch -M main',
    'git remote add origin https://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@github.com/k-oasis/love.git',
    'git push -u origin main'
]

for cmd in commands:
    # Print command (with token hidden)
    safe_cmd = cmd.replace('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', '****')
    print(f"Executing: {safe_cmd}")
    # Execute command
    result = await terminal.run(cmd)
    print(f"Output:\n{result}")
    print("-" * 50)
# Out:
# Executing: echo "# love" >> README.md
# Output:
#
# --------------------------------------------------
# Executing: git init
# Output:
#
# Reinitialized existing Git repository in /data/chats/xos6sd/workspace/.git/
#
# --------------------------------------------------
# Executing: git add README.md
# Output:
#
#
# --------------------------------------------------
# Executing: git commit -m "first commit"
# Output:
#
# On branch main
# nothing to commit, working tree clean
#
# --------------------------------------------------
# Executing: git branch -M main
# Output:
#
#
# --------------------------------------------------
# Executing: git remote add origin https://****@github.com/k-oasis/love.git
# Output:
#
#
# --------------------------------------------------
# Executing: git push -u origin main
# Output:
#
# Uploading LFS objects: 100% (2/2), 5.6 KB | 0 B/s, done.
# To https://github.com/k-oasis/love.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/k-oasis/love.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
#
# --------------------------------------------------

# %%
from metagpt.tools.libs.terminal import Terminal

terminal = Terminal()

# Remove existing .git and README first
await terminal.run('rm -rf .git')
await terminal.run('rm -f README.md')

# Execute the exact commands as specified
commands = [
    'echo "# love" >> README.md',
    'git init',
    'git add README.md',
    'git commit -m "first commit"',
    'git branch -M main',
    'git remote add origin https://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@github.com/k-oasis/love.git',
    'git push -u origin main'
]

for cmd in commands:
    # Print command (with token hidden)
    safe_cmd = cmd.replace('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', '****')
    print(f"Executing: {safe_cmd}")
    # Execute command
    result = await terminal.run(cmd)
    print(f"Output:\n{result}")
    print("-" * 50)
# Out:
# Executing: echo "# love" >> README.md
# Output:
#
#
# --------------------------------------------------
# Executing: git init
# Output:
#
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /data/chats/xos6sd/workspace/.git/
#
# --------------------------------------------------
# Executing: git add README.md
# Output:
#
#
# --------------------------------------------------
# Executing: git commit -m "first commit"
# Output:
#
# On branch master
# nothing to commit, working tree clean
#
# --------------------------------------------------
# Executing: git branch -M main
# Output:
#
#
# --------------------------------------------------
# Executing: git remote add origin https://****@github.com/k-oasis/love.git
# Output:
#
#
# --------------------------------------------------
# Executing: git push -u origin main
# Output:
#
# Uploading LFS objects: 100% (2/2), 5.6 KB | 0 B/s, done.
# To https://github.com/k-oasis/love.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/k-oasis/love.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
#
# --------------------------------------------------
